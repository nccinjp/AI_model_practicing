# %% [markdown]
# # Load datasets

# %% [markdown]
# # Stock trend classifiaction_train Inception Time

# %%
import numpy as np
import pandas as pd

CLASSES = [ "Bull" , "Bear"  ]  
LABEL_BULL = CLASSES.index( "Bull" )
LABEL_BEAR = CLASSES.index( "Bear" )

datasets = np.load("datasets.npz")
x_train, y_train = datasets["x_train"],datasets["y_train"]
x_val,y_val = datasets["x_val"],datasets["y_val"]
x_test,y_test = datasets["x_test"],datasets["y_test"]
                                             
# Label distribution 
label_distribution = pd.DataFrame([{"Dataset" : "train",
                                                         "Bull":np.count_nonzero(y_train == LABEL_BULL),
                                                         "Bear": np.count_nonzero(y_train == LABEL_BEAR)},
                                                         {"Dataset" : "val",
                                                         "Bull":np.count_nonzero(y_val == LABEL_BULL),
                                                         "Bear": np.count_nonzero(y_val == LABEL_BEAR)},
                                                         {"Dataset" : "test",
                                                         "Bull":np.count_nonzero(y_test == LABEL_BULL),
                                                         "Bear": np.count_nonzero(y_test == LABEL_BEAR)}])
label_distribution
# Out:
#   Dataset  Bull  Bear
# 0   train   888   803
# 1     val   263   220
# 2    test   120   120

# %% [markdown]
# # Construct model

# %%
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Concatenate, \
                                                        BatchNormalization, Activation, \
                                                        Add, GlobalAveragePooling1D, Dense
from tensorflow.keras.models import Model 

def inception_module(input_tensor):
    bottleneck = Conv1D(filters=32, kernel_size=1, padding="same", activation=None,
                       use_bias=False) (input_tensor)
    conv3 = Conv1D(filters=32, kernel_size=3, padding="same", activation=None,
                       use_bias=False) (bottleneck)
    conv5 = Conv1D(filters=32, kernel_size=5, padding="same", activation=None,
                       use_bias=False) (bottleneck)
    conv7 = Conv1D(filters=32, kernel_size=7, padding="same", activation=None,
                       use_bias=False) (bottleneck)
    mp = MaxPooling1D(pool_size=3, strides=1,padding="same")(input_tensor)
    mpbottleneck = Conv1D(filters=32, kernel_size=1, padding="same",activation=None,
                         use_bias=False)(mp)
    
    x = Concatenate(axis=-1)([conv3,conv5,conv7, mpbottleneck])
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def shortcut_layer(input_tensor1, input_tensor2):
    shortcut = Conv1D(filters=input_tensor2.shape[-1], kernel_size=1, padding="same", activation=None, use_bias=False)(input_tensor1)
    shortcut = BatchNormalization()(shortcut)
    
    x = Add()([shortcut, input_tensor2])
    x = Activation("relu")(x)
    return x

#Build model
n_time_steps = x_train.shape[1]
n_features = x_train.shape[2]

input_layer = Input(shape=(n_time_steps, n_features))
x = input_layer
input_residual = input_layer

for i in range(6):
    x = inception_module(x)
    
    if i % 3 == 2 :
        x = shortcut_layer(input_residual, x)
        input_residual = x

x = GlobalAveragePooling1D()(x)
output_layer = Dense(len(CLASSES), activation="softmax" )(x)

model = Model(inputs = input_layer, outputs= output_layer)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 7)]     0           []
#
#  conv1d (Conv1D)                (None, 100, 32)      224         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 100, 7)       0           ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 100, 32)      3072        ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 100, 32)      5120        ['conv1d[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 100, 32)      7168        ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 100, 32)      224         ['max_pooling1d[0][0]']
#
#  concatenate (Concatenate)      (None, 100, 128)     0           ['conv1d_1[0][0]',
#                                                                   'conv1d_2[0][0]',
#                                                                   'conv1d_3[0][0]',
#                                                                   'conv1d_4[0][0]']
#
#  batch_normalization (BatchNorm  (None, 100, 128)    512         ['concatenate[0][0]']
#  alization)
#
#  activation (Activation)        (None, 100, 128)     0           ['batch_normalization[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 100, 32)      4096        ['activation[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 100, 128)    0           ['activation[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 100, 32)      3072        ['conv1d_5[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 100, 32)      5120        ['conv1d_5[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 100, 32)      7168        ['conv1d_5[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 100, 32)      4096        ['max_pooling1d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 100, 128)     0           ['conv1d_6[0][0]',
#                                                                   'conv1d_7[0][0]',
#                                                                   'conv1d_8[0][0]',
#                                                                   'conv1d_9[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 100, 128)    512         ['concatenate_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 100, 128)     0           ['batch_normalization_1[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 100, 32)      4096        ['activation_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 100, 128)    0           ['activation_1[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 100, 32)      3072        ['conv1d_10[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 100, 32)      5120        ['conv1d_10[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 100, 32)      7168        ['conv1d_10[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 100, 32)      4096        ['max_pooling1d_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 100, 128)     0           ['conv1d_11[0][0]',
#                                                                   'conv1d_12[0][0]',
#                                                                   'conv1d_13[0][0]',
#                                                                   'conv1d_14[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 100, 128)     896         ['input_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 100, 128)    512         ['concatenate_2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 100, 128)    512         ['conv1d_15[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 100, 128)     0           ['batch_normalization_2[0][0]']
#
#  add (Add)                      (None, 100, 128)     0           ['batch_normalization_3[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 100, 128)     0           ['add[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 100, 32)      4096        ['activation_3[0][0]']
#  max_pooling1d_3 (MaxPooling1D)  (None, 100, 128)    0           ['activation_3[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 100, 32)      3072        ['conv1d_16[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 100, 32)      5120        ['conv1d_16[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 100, 32)      7168        ['conv1d_16[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 100, 32)      4096        ['max_pooling1d_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 100, 128)     0           ['conv1d_17[0][0]',
#                                                                   'conv1d_18[0][0]',
#                                                                   'conv1d_19[0][0]',
#                                                                   'conv1d_20[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 100, 128)    512         ['concatenate_3[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 100, 128)     0           ['batch_normalization_4[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 100, 32)      4096        ['activation_4[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 100, 128)    0           ['activation_4[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 100, 32)      3072        ['conv1d_21[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 100, 32)      5120        ['conv1d_21[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 100, 32)      7168        ['conv1d_21[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 100, 32)      4096        ['max_pooling1d_4[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 100, 128)     0           ['conv1d_22[0][0]',
#                                                                   'conv1d_23[0][0]',
#                                                                   'conv1d_24[0][0]',
#                                                                   'conv1d_25[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 100, 128)    512         ['concatenate_4[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 100, 128)     0           ['batch_normalization_5[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 100, 32)      4096        ['activation_5[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 100, 128)    0           ['activation_5[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 100, 32)      3072        ['conv1d_26[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 100, 32)      5120        ['conv1d_26[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 100, 32)      7168        ['conv1d_26[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 100, 32)      4096        ['max_pooling1d_5[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 100, 128)     0           ['conv1d_27[0][0]',
#                                                                   'conv1d_28[0][0]',
#                                                                   'conv1d_29[0][0]',
#                                                                   'conv1d_30[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 100, 128)     16384       ['activation_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 100, 128)    512         ['concatenate_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 100, 128)    512         ['conv1d_31[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 100, 128)     0           ['batch_normalization_6[0][0]']
#
#  add_1 (Add)                    (None, 100, 128)     0           ['batch_normalization_7[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 100, 128)     0           ['add_1[0][0]']
#
#  global_average_pooling1d (Glob  (None, 128)         0           ['activation_7[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 2)            258         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 155,202
# Trainable params: 153,154
# Non-trainable params: 2,048
# __________________________________________________________________________________________________

# %% [markdown]
# #  Train model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model_checkpoint = ModelCheckpoint(filepath="best_model.hdf5", monitor ="val_loss",
                                  save_best_only=True)
early_stopping = EarlyStopping(monitor="val_loss", patience= 100, restore_best_weights=True)
callbacks = [model_checkpoint, early_stopping]

train_history = model.fit(x_train, to_categorical(y_train),
                         validation_data=(x_val, to_categorical(y_val)),
                         batch_size= 2048, epochs=1000, callbacks=[callbacks])
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 7s 7s/step - loss: 0.7370 - accuracy: 0.4826 - val_loss: 33.8841 - val_accuracy: 0.5445
# Epoch 2/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.9493 - accuracy: 0.4885 - val_loss: 9.8944 - val_accuracy: 0.5445
# Epoch 3/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.7055 - accuracy: 0.5316 - val_loss: 2.9602 - val_accuracy: 0.4555
# Epoch 4/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.8086 - accuracy: 0.5139 - val_loss: 3.7919 - val_accuracy: 0.4555
# Epoch 5/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.7471 - accuracy: 0.5133 - val_loss: 0.7841 - val_accuracy: 0.4720
# Epoch 6/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6937 - accuracy: 0.5186 - val_loss: 2.2543 - val_accuracy: 0.5445
# Epoch 7/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.7218 - accuracy: 0.5151 - val_loss: 2.1958 - val_accuracy: 0.5445
# Epoch 8/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.7185 - accuracy: 0.5050 - val_loss: 0.8669 - val_accuracy: 0.5445
# Epoch 9/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6938 - accuracy: 0.5204 - val_loss: 1.6680 - val_accuracy: 0.4555
# Epoch 10/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6922 - accuracy: 0.5240 - val_loss: 3.0505 - val_accuracy: 0.4555
# Epoch 11/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.7028 - accuracy: 0.5145 - val_loss: 3.3135 - val_accuracy: 0.4555
# Epoch 12/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6987 - accuracy: 0.5163 - val_loss: 2.8032 - val_accuracy: 0.4555
# Epoch 13/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6894 - accuracy: 0.5334 - val_loss: 2.0481 - val_accuracy: 0.4555
# Epoch 14/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6901 - accuracy: 0.5316 - val_loss: 1.5355 - val_accuracy: 0.4555
# Epoch 15/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6953 - accuracy: 0.5198 - val_loss: 1.4663 - val_accuracy: 0.4555
# Epoch 16/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6940 - accuracy: 0.5269 - val_loss: 1.7396 - val_accuracy: 0.4555
# Epoch 17/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6881 - accuracy: 0.5494 - val_loss: 2.1498 - val_accuracy: 0.4555
# Epoch 18/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6862 - accuracy: 0.5529 - val_loss: 2.4157 - val_accuracy: 0.4555
# Epoch 19/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6893 - accuracy: 0.5381 - val_loss: 2.3615 - val_accuracy: 0.4555
# Epoch 20/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6906 - accuracy: 0.5251 - val_loss: 2.0105 - val_accuracy: 0.4555
# Epoch 21/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.6877 - accuracy: 0.5476 - val_loss: 1.5380 - val_accuracy: 0.4555
# Epoch 22/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.6843 - accuracy: 0.5594 - val_loss: 1.1473 - val_accuracy: 0.4555
# Epoch 23/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6842 - accuracy: 0.5594 - val_loss: 0.9600 - val_accuracy: 0.4555
# Epoch 24/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6858 - accuracy: 0.5565 - val_loss: 0.9520 - val_accuracy: 0.4555
# Epoch 25/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6857 - accuracy: 0.5547 - val_loss: 1.0648 - val_accuracy: 0.4555
# Epoch 26/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6836 - accuracy: 0.5535 - val_loss: 1.2249 - val_accuracy: 0.4555
# Epoch 27/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.
1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6153 - accuracy: 0.6263 - val_loss: 0.7328 - val_accuracy: 0.4990
# Epoch 119/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.7297 - accuracy: 0.5991 - val_loss: 0.7310 - val_accuracy: 0.5611
# Epoch 120/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5371 - accuracy: 0.7410 - val_loss: 0.7592 - val_accuracy: 0.5321
# Epoch 121/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.6321 - accuracy: 0.6263 - val_loss: 0.9649 - val_accuracy: 0.5072
# Epoch 122/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5692 - accuracy: 0.6984 - val_loss: 1.3643 - val_accuracy: 0.4907
# Epoch 123/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5824 - accuracy: 0.6700 - val_loss: 0.8232 - val_accuracy: 0.5300
# Epoch 124/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5710 - accuracy: 0.6949 - val_loss: 0.8295 - val_accuracy: 0.5445
# Epoch 125/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.5514 - accuracy: 0.7451 - val_loss: 0.8612 - val_accuracy: 0.5549
# Epoch 126/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.5549 - accuracy: 0.7286 - val_loss: 0.8825 - val_accuracy: 0.5631
# Epoch 127/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5514 - accuracy: 0.7398 - val_loss: 1.0068 - val_accuracy: 0.5445
# Epoch 128/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5332 - accuracy: 0.7516 - val_loss: 1.0717 - val_accuracy: 0.5445
# Epoch 129/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5386 - accuracy: 0.7351 - val_loss: 0.9939 - val_accuracy: 0.5445
# Epoch 130/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5263 - accuracy: 0.7487 - val_loss: 0.9209 - val_accuracy: 0.5445
# Epoch 131/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5118 - accuracy: 0.7652 - val_loss: 0.8824 - val_accuracy: 0.5445
# Epoch 132/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5082 - accuracy: 0.7700 - val_loss: 0.8272 - val_accuracy: 0.5424
# Epoch 133/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4910 - accuracy: 0.7830 - val_loss: 0.7698 - val_accuracy: 0.5569
# Epoch 134/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4848 - accuracy: 0.7907 - val_loss: 0.7618 - val_accuracy: 0.5342
# Epoch 135/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4746 - accuracy: 0.7960 - val_loss: 0.7602 - val_accuracy: 0.5300
# Epoch 136/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4620 - accuracy: 0.7966 - val_loss: 0.7385 - val_accuracy: 0.5010
# Epoch 137/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4538 - accuracy: 0.8196 - val_loss: 0.7198 - val_accuracy: 0.5487
# Epoch 138/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.4433 - accuracy: 0.8273 - val_loss: 0.7819 - val_accuracy: 0.5487
# Epoch 139/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4317 - accuracy: 0.8291 - val_loss: 0.7299 - val_accuracy: 0.5445
# Epoch 140/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4270 - accuracy: 0.8368 - val_loss: 0.9116 - val_accuracy: 0.5507
# Epoch 141/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.4468 - accuracy: 0.7871 - val_loss: 0.7065 - val_accuracy: 0.5694
# Epoch 142/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4899 - accuracy: 0.7433 - val_loss: 0.7901 - val_accuracy: 0.5611
# Epoch 143/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4305 - accuracy: 0.8019 - val_loss: 0.7956 - val_accuracy: 0.5507
# Epoch 144/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.4059 - accuracy: 0.8356 - val_loss: 0.7230 - val_accuracy: 0.5652
# Epoch 145/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4114 - accuracy: 0.8303 - val_loss: 0.7008 - val_accuracy: 0.5631
# Epoch 146/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3957 - accuracy: 0.8486 - val_loss: 0.7356 - val_accuracy: 0.5487
# Epoch 147/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.3771 - accuracy: 0.8575 - val_loss: 0.7629 - val_accuracy: 0.5631
# Epoch 148/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3674 - accuracy: 0.8675 - val_loss: 0.7459 - val_accuracy: 0.5507
# Epoch 149/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3633 - accuracy: 0.8729 - val_loss: 0.7623 - val_accuracy: 0.5466
# Epoch 150/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3373 - accuracy: 0.8930 - val_loss: 0.8516 - val_accuracy: 0.5466
# Epoch 151/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3421 - accuracy: 0.8794 - val_loss: 0.7736 - val_accuracy: 0.5321
# Epoch 152/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3660 - accuracy: 0.8468 - val_loss: 1.1442 - val_accuracy: 0.5549
# Epoch 153/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5280 - accuracy: 0.7114 - val_loss: 0.7542 - val_accuracy: 0.5383
# Epoch 154/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.5084 - accuracy: 0.7428 - val_loss: 0.7563 - val_accuracy: 0.5238
# Epoch 155/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3889 - accuracy: 0.8409 - val_loss: 0.7672 - val_accuracy: 0.5176
# Epoch 156/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4742 - accuracy: 0.7510 - val_loss: 0.8455 - val_accuracy: 0.4700
# Epoch 157/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3906 - accuracy: 0.8427 - val_loss: 2.1285 - val_accuracy: 0.4534
# Epoch 158/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.4176 - accuracy: 0.8037 - val_loss: 3.0896 - val_accuracy: 0.4555
# Epoch 159/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.3667 - accuracy: 0.8752 - val_loss: 3.2538 - val_accuracy: 0.4555
# Epoch 160/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3870 - accuracy: 0.8315 - val_loss: 3.2437 - val_accuracy: 0.4555
# Epoch 161/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3640 - accuracy: 0.8658 - val_loss: 4.1316 - val_accuracy: 0.4555
# Epoch 162/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3353 - accuracy: 0.8918 - val_loss: 4.9436 - val_accuracy: 0.4555
# Epoch 163/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3500 - accuracy: 0.8575 - val_loss: 4.9625 - val_accuracy: 0.4555
# Epoch 164/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3349 - accuracy: 0.8764 - val_loss: 4.5507 - val_accuracy: 0.4555
# Epoch 165/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.3303 - accuracy: 0.8823 - val_loss: 5.4151 - val_accuracy: 0.4555
# Epoch 166/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3347 - accuracy: 0.8788 - val_loss: 6.3664 - val_accuracy: 0.4555
# Epoch 167/1000
# 1/1 [==============================] - 2s 2s/step - loss: 0.3476 - accuracy: 0.8557 - val_loss: 3.4228 - val_accuracy: 0.4555
# Epoch 168/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.3480 - accuracy: 0.8516 - val_loss: 3.3023 - val_accuracy: 0.4555

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")
fig, axes = plt.subplots(2,1,figsize=(16,12))

axes[0].set_title("Loss")
axes[0].set_yscale("log")
axes[0].plot(train_history.history["loss"], label="Training")
axes[0].plot(train_history.history["val_loss"], label= "Validation")
axes[0].legend()

axes[1].set_title("Accuracy")
axes[1].set_xlabel("Epoch")
axes[1].plot(train_history.history["accuracy"], label="Training")
axes[1].plot(train_history.history["val_accuracy"], label= "Validation")
axes[1].legend()

# %%
#股市分析員都喜歡從陰陽燭圖找圖案　所以模型擅長分析ＩＭＡＧＥ
#時間連續性　ＴＩＭＥ　ＳＥＲＩＥＳ
#股市預測數值不用　只需要預測漲跌　進行分裂ＣＬＡＳＳＩＦＩＣＡＴＩＯＮ
#ＩＮＣＥＰＴＩＯＮ　ＡＬＥＸＮＥＴ都是有關圖像ＡＩ的字眼
#裡面的ＣＯＮＶＯＬＵＴＩＯＮ可以用來分析陰陽燭圖

# %%
#
